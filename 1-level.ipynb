# %% [markdown]
# ### 1. 创建服务器
# 对于新手而言, 创建服务器也很简单, 不做赘述, 选择自己喜欢的cuda版本镜像创建实例就可以.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 有意思的思考
# 1. 镜像是怎么做出来的
#
# 猜测是Docker镜像,  根据官方的[Dockerfile](https://gitlab.com/nvidia/container-images/cuda/-/blob/master/dist/12.5.0/ubuntu2004/base/Dockerfile), 可以自己创建一个试试.

# %% [markdown]
# ### 2. 连接服务器
#
# #### 2.1 直接ssh
# 打开本地终端, 复制ssh链接命令
#
# #### 2.2 使用Vscode远程连接
# 这个比较方便, 推荐!!!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 连接完成后, 就可以像本地一样操作服务器的文件和终端了, 超级好用.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. 开工

# %%
! pip install gradio==4.29.0
# 不知道为什么, InternStudio的服务器运行文件写入操作非常的慢, 是不是可以优化一下

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 启动程序
#
# `python hello_world.py `
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 运气好的话, VsCode 会弹出一个端口转发的提示, 就可以在本地浏览器打开页面了, 神奇!

# %% [markdown]
# ![image.png](attachment:image.png)
